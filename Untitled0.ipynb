# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ML

# Tambahkan file baru (misalnya)
with open("contoh_dari_colab.txt", "w") as f:
    f.write("Isi file dari Colab!")

# Konfigurasi Git
# !git config --global user.email "fairuzmdy86@email.com"
# !git config --global user.name "Fairuz Maulidya"

# Commit dan push
# !git add .
# !git commit -m "Push dari Colab - file baru"
# !git push origin main
# Out:
# /content/drive/MyDrive/ML
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
